# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# %pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 92.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
# ...
#   Created wheel for labelme: filename=labelme-5.5.0-py3-none-any.whl size=1437464 sha256=e616324109fbc6ae7617c0bfad7785d760c13115f23759964946387c074dc9be
# ...

# %%
# !python labelme2yolo.py --json_dir datasets/check_tron_0_1 --val_size 0.2 --seg
# Out:
# Converting image_cropped_399.json for train ...
# Converting 20240505_034345_crop.json for train ...
# Converting 20240505_033929_crop.json for train ...
# Converting image_cropped_418.json for train ...
# Converting 20240811_135345_crop.json for train ...
# Converting 20240505_033721_crop.json for train ...
# Converting 20240505_034752_crop.json for train ...
# Converting 20240505_033904_crop.json for train ...
# Converting 20240505_034035_crop.json for train ...
# Converting 20240811_143236_crop.json for train ...
# Converting 05.json for train ...
# Converting 20240505_040810_crop.json for train ...
# Converting 20240505_042314_crop.json for train ...
# Converting 27.json for train ...
# Converting 20240811_143150_crop.json for train ...
# Converting 20240811_092712_crop.json for train ...
# Converting 20240729_144929_crop.json for train ...
# Converting 20240505_040540_crop.json for train ...
# Converting 20240504_214413_crop.json for train ...
# ...
